# %%
from magcvs_library.science import find_candidates_from_parquet
from magcvs_library.plots import plot_periodogram
import warnings
# Disabling FutureWarnings:
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ## 20250410

# %%
candidates_g, candidates_r = find_candidates_from_parquet('../../data/to_classify_20250410')
# Out:
# Splitting data by filter: 100%|██████████| 1935/1935
# Extracting features: 100%|██████████| 1859/1859
# Extracting features: 100%|██████████| 1933/1933

# %%
candidates_g
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF17aacsclx   12.0                     no
# 1  ZTF18aairqhf   11.0                     no
# 2  ZTF18aahimjm   10.0                     no
# 3  ZTF18abikqec    7.0                     no
# 4  ZTF18adjsnrs    6.0                     no
# 5  ZTF18acwyyqy    NaN                    yes
# 6  ZTF18aawytjj    NaN                    yes

# %%
for id in candidates_g['objectId']:
    plot_periodogram(id)

# %%
candidates_r
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18abmbbcd   17.0                     no
# 1  ZTF18abncuii   10.0                     no
# 2  ZTF18ablrmio    8.0                     no
# 3  ZTF17aaadbne    7.0                    yes
# 4  ZTF18acwyyqy    7.0                     no
# 5  ZTF17aaadbne    NaN                    yes
# 6  ZTF18abegqvd    NaN                    yes

# %%
for id in candidates_r['objectId']:
    plot_periodogram(id)

# %% [markdown]
# ## 20250410 (with cds)

# %%
candidates_g2, candidates_r2 = find_candidates_from_parquet('../../data/negative_class_many_days/CVs_20250410_with_cds')
# Out:
# Splitting data by filter: 100%|██████████| 11333/11333
# Extracting features: 100%|██████████| 10122/10122
# Extracting features: 100%|██████████| 11319/11319

# %%
candidates_g2
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18admjcqv    4.0                     no
# 1  ZTF18aazfblx    3.0                     no
# 2  ZTF18aazmbhk    3.0                     no
# 3  ZTF18aajtnfn    3.0                     no
# 4  ZTF18aauqqgj    2.0                     no
# 5  ZTF18aaxltkf    NaN                    yes
# 6  ZTF18aaveltv    NaN                    yes

# %%
for id in candidates_g2['objectId']:
    plot_periodogram(id)

# %%
candidates_r2
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18admjcqv    7.0                     no
# 1  ZTF21abhrdqb    6.0                     no
# 2  ZTF18adlyqny    4.0                     no
# 3  ZTF18aboudmq    4.0                     no
# 4  ZTF19abbudgp    3.0                     no
# 5  ZTF18aazuxdv    NaN                    yes
# 6  ZTF18abebeye    NaN                    yes

# %%
for id in candidates_r2['objectId']:
    plot_periodogram(id)

# %% [markdown]
# ## 20250411

# %%
candidates_g3, candidates_r3 = find_candidates_from_parquet('../../data/negative_class_many_days/CVs_20250411_with_cds')
# Out:
# Splitting data by filter: 100%|██████████| 1582/1582
# Extracting features: 100%|██████████| 1536/1536
# Extracting features: 100%|██████████| 1575/1575

# %%
candidates_g3
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18aauqqgj    4.0                     no
# 1  ZTF18aaxvbvw    3.0                     no
# 2  ZTF18aazmbhk    3.0                     no
# 3  ZTF19aatjhsl    3.0                     no
# 4  ZTF18abeepdl    2.0                     no
# 5  ZTF18adjvsyz    NaN                    yes
# 6  ZTF17aabopig    NaN                    yes

# %%
for id in candidates_g3['objectId']:
    plot_periodogram(id)

# %%
candidates_r3
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18abbmxzo    6.0                     no
# 1  ZTF18aboudmq    5.0                     no
# 2  ZTF18abjucfj    4.0                     no
# 3  ZTF18abiuhdq    4.0                     no
# 4  ZTF19abbudgp    4.0                     no
# 5  ZTF18aazlxjt    NaN                    yes
# 6  ZTF19aafnqic    NaN                    yes

# %%
for id in candidates_r3['objectId']:
    plot_periodogram(id)

# %% [markdown]
# ## 20250415

# %%
candidates_g4, candidates_r4 = find_candidates_from_parquet('../../data/negative_class_many_days/CVs_20250415_with_cds')
# Out:
# Splitting data by filter: 100%|██████████| 1729/1729
# Extracting features: 100%|██████████| 1728/1728
# Extracting features: 100%|██████████| 1729/1729

# %%
candidates_g4
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18acvixrt    4.0                     no
# 1  ZTF18aazxwhj    3.0                     no
# 2  ZTF19aatjhsl    3.0                     no
# 3  ZTF19aavhcxu    3.0                     no
# 4  ZTF18absqyhv    3.0                     no
# 5  ZTF18abrzhjo    NaN                    yes
# 6  ZTF18ablwqif    NaN                    yes

# %%
for id in candidates_g4['objectId']:
    plot_periodogram(id)

# %%
candidates_r4
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18aazrrhy    6.0                     no
# 1  ZTF18abaaesi    5.0                     no
# 2  ZTF18aagrgbf    4.0                     no
# 3  ZTF18abkeqko    4.0                     no
# 4  ZTF18ablhpip    4.0                     no
# 5  ZTF18abypjnn    NaN                    yes
# 6  ZTF18abjjark    NaN                    yes

# %%
for id in candidates_r4['objectId']:
    plot_periodogram(id)

# %% [markdown]
# ## 20250416

# %%
candidates_g5, candidates_r5 = find_candidates_from_parquet('../../data/negative_class_many_days/CVs_20250416_with_cds')
# Out:
# Splitting data by filter: 100%|██████████| 2613/2613
# Extracting features: 100%|██████████| 2603/2603
# Extracting features: 100%|██████████| 2608/2608

# %%
candidates_g5
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18aaxulce    5.0                     no
# 1  ZTF18admjcqv    5.0                     no
# 2  ZTF18aamgthw    4.0                     no
# 3  ZTF18aavzllz    4.0                     no
# 4  ZTF18acyhusd    4.0                     no
# 5  ZTF18aaiireu    NaN                    yes
# 6  ZTF18aayecwm    NaN                    yes

# %%
for id in candidates_g5['objectId']:
    plot_periodogram(id)

# %%
candidates_r5
# Out:
#        objectId  score ZTF18aaadlpa_neighbors
# 0  ZTF18admjcqv    8.0                     no
# 1  ZTF18adlyqny    5.0                     no
# 2  ZTF17aaapvrl    4.0                     no
# 3  ZTF17aaadbne    3.0                     no
# 4  ZTF18aazvhbz    3.0                     no
# 5  ZTF18aawbmyf    NaN                    yes
# 6  ZTF18abjjark    NaN                    yes

# %%
for id in candidates_r5['objectId']:
    plot_periodogram(id)
